# %%
import pandas as pd
import numpy as np
from ast import literal_eval
# Out:
# /tmp/ipykernel_6205/250612768.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
def select_columns(df) -> any:
    '''Selects fields from _id, _source.data, _source.assets, and _source.source_data'''
    pattern = r'^(_id|_source\.(data|assets|source_data|sources.source_ids))'
    filtered_columns = df.columns.str.contains(pattern, regex=True)
    df = df.loc[:, filtered_columns]
    return df

# %%
def remove_parent_keys(column):
    '''Df contains parent keys. We remove all of them by removing any column wit {}. We also remove _source.source_data which starts with [{'''
    return any(isinstance(value, str) and (value.startswith('{') or value.startswith('[{')) for value in column)

# %%
def row_to_nan(row):
    '''Convert [NaN, NaN] values in list to NaN'''
    try:
        row_list = eval(row)
        if all(val is None for val in row_list):
            return np.nan
    except (ValueError, SyntaxError, NameError, TypeError):
        pass
    return row

# %%
def main():
    df = pd.read_parquet('../../parquet/TheOfficialBoard.parquet')
    df = select_columns(df)

    remove_columns = [column for column in df if remove_parent_keys(df[column])]
    df = df.drop(columns=remove_columns)
    
    
    for column in df.columns:
        df[column] = df[column].apply(row_to_nan)

    df.to_parquet('../../parquet/TheOfficialBoard.parquet')

    return df

# %%
if __name__ == '__main__':
    main()
# Out:
# C:\Users\AlbinTouma\AppData\Local\Temp\ipykernel_15872\124473536.py:4: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   filtered_columns = df.columns.str.contains(pattern, regex=True)
# c:\Users\AlbinTouma\AppData\Local\Programs\Python\Python310\lib\site-packages\pyarrow\pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
#                                     _id       _source.sources.source_ids  \
# 0               SM:S:1GYJGG:VijaySharma  [S:1GYJGG [The Official Board]]
# 1          SM:S:1GYJGG:VijayKumarSharma  [S:1GYJGG [The Official Board]]
# 2         SM:S:1GYJGG:ManuelMarinGuzman  [S:1GYJGG [The Official Board]]
# 3          SM:S:1GYJGG:MohammedAlJadaan  [S:1GYJGG [The Official Board]]
# 4                SM:S:1GYJGG:OlafScholz  [S:1GYJGG [The Official Board]]
# ...                                 ...                              ...
# 20918            SM:S:1GYJGG:HitoshiIto  [S:1GYJGG [The Official Board]]
# 20919        SM:S:1GYJGG:AlistairDormer  [S:1GYJGG [The Official Board]]
# 20920      SM:S:1GYJGG:HideakiTakahashi  [S:1GYJGG [The Official Board]]
# 20921            SM:S:1GYJGG:HarishBhat  [S:1GYJGG [The Official Board]]
# 20922  SM:S:1GYJGG:MikhailPoluboyarinov  [S:1GYJGG [The Official Board]]
#
#                               _source.assets.asset_types  \
# 0                                             [document]
# 1                                             [document]
# 2                                             [document]
# 3                                             [document]
# 4                                   [document, document]
# ...                                                  ...
# 20918                                         [document]
# 20919                     [document, document, document]
# 20920                                         [document]
# 20921  [document, document, document, document, docum...
# 20922                                         [document]
#
#                             _source.assets.external_urls  \
# 0      [http://www.theofficialboard.com/org-chart/bal...
# 1      [http://www.theofficialboard.com/org-chart/tat...
# 2      [http://www.theofficialboard.com/org-chart/end...
# 3      [http://www.theofficialboard.com/org-chart/sau...
# 4      [http://www.theofficialboard.com/org-chart/kfw...
# ...                                                  ...
# 20918  [http://www.theofficialboard.com/org-chart/hit...
# 20919  [http://www.theofficialboard.com/org-chart/ans...
# 20920  [http://www.theofficialboard.com/org-chart/hit...
# 20921  [http://www.theofficialboard.com/org-chart/inf...
# 20922  [http://www.theofficialboard.com/org-chart/aer...
#
#                                _source.assets.source_ids  \
# 0                        [S:1GYJGG [The Official Board]]
# 1                        [S:1GYJGG [The Official Board]]
# 2                        [S:1GYJGG [The Official Board]]
# 3                        [S:1GYJGG [The Official Board]]
# 4      [S:1GYJGG [The Official Board], S:1GYJGG [The ...
# ...                                                  ...
# 20918                    [S:1GYJGG [The Official Board]]
# 20919  [S:1GYJGG [The Official Board], S:1GYJGG [The ...
# 20920                    [S:1GYJGG [The Official Board]]
# 20921  [S:1GYJGG [The Official Board], S:1GYJGG [The ...
# 20922                    [S:1GYJGG [The Official Board]]
#
#       _source.assets.photo_count _source.data.aml_types.aml_type  \
# 0                            [0]                   [pep-class-3]
# 1                            [0]                   [pep-class-3]
# 2                            [0]                   [pep-class-3]
# 3                            [0]                   [pep-class-3]
# 4                         [0, 0]                   [pep-class-3]
# ...                          ...                             ...
# 20918                        [0]                   [pep-class-3]
# 20919                  [0, 0, 0]                   [pep-class-3]
# 20920                        [0]                   [pep-class-3]
# 20921      [0, 0, 0, 0, 0, 0, 0]                   [pep-class-3]
# 20922                        [0]                   [pep-class-3]
#
#       _source.data.aml_types.end_date _source.data.aml_types.start_date  \
# 0                              [None]                            [None]
# 1                              [None]                            [None]
# 2                              [None]                            [None]
# 3                              [None]                            [None]
# 4                              [None]                            [None]
# ...                               ...                               ...
# 20918                          [None]                            [None]
# 20919                          [None]                            [None]
# 20920                          [None]                            [None]
# 20921                          [None]                            [None]
# 20922                          [None]                            [None]
#
#                        _source.data.display_fields.title  ...  \
# 0            [Chamber, Company, Other Info, Related Url]  ...
# 1      [Chamber, Company, Other Info, Parent Company,...  ...
# 2      [Chamber, Company, Other Info, Parent Company,...  ...
# 3            [Chamber, Company, Other Info, Related Url]  ...
# 4      [Chamber, Chamber, Company, Company, Other Inf...  ...
# ...                                                  ...  ...
# 20918        [Chamber, Company, Other Info, Related Url]  ...
# 20919  [Chamber, Chamber, Chamber, Company, Company, ...  ...
# 20920        [Chamber, Company, Other Info, Related Url]  ...
# 20921  [Chamber, Chamber, Chamber, Chamber, Chamber, ...  ...
# 20922        [Chamber, Company, Other Info, Related Url]  ...
#
#       _source.data.entity_types.entity_type  \
# 0                                  [person]
# 1                                  [person]
# 2                                  [person]
# 3                                  [person]
# 4                                  [person]
# ...                                     ...
# 20918                              [person]
# 20919                              [person]
# 20920                              [person]
# 20921                              [person]
# 20922                              [person]
#
#       _source.data.locations.location_type     _source.data.locations.name  \
# 0                                [general]                         [India]
# 1                                [general]                         [India]
# 2                                [general]                         [Spain]
# 3                                [general]                  [Saudi Arabia]
# 4                       [general, general]              [Germany, Denmark]
# ...                                    ...                             ...
# 20918                            [general]                         [Japan]
# 20919          [general, general, general]  [United Kingdom, Italy, Japan]
# 20920                            [general]                         [Japan]
# 20921                            [general]                         [India]
# 20922                            [general]            [Russian Federation]
#
#                                  _source.data.names.name  \
# 0                                         [Vijay Sharma]
# 1                                   [Vijay Kumar Sharma]
# 2                                  [Manuel Marín Guzmán]
# 3                                   [Mohammed al Jadaan]
# 4                             [Olaf Scholz, Olaf Scholz]
# ...                                                  ...
# 20918                                      [Hitoshi Ito]
# 20919  [Alistair Dormer, Alistair Dormer, Alistair Do...
# 20920                                [Hideaki Takahashi]
# 20921  [Harish Bhat, Harish Bhat, Harish Bhat, Harish...
# 20922                            [Mikhail Poluboyarinov]
#
#                             _source.data.names.name_type  \
# 0                                              [primary]
# 1                                              [primary]
# 2                                              [primary]
# 3                                              [primary]
# 4                                       [primary, alias]
# ...                                                  ...
# 20918                                          [primary]
# 20919                            [primary, alias, alias]
# 20920                                          [primary]
# 20921  [primary, alias, alias, alias, alias, alias, a...
# 20922                                          [primary]
#
#       _source.data.names.primary_name _source.data.occupations.occupation  \
# 0                        Vijay Sharma  [Director of a State Owned Entity]
# 1                  Vijay Kumar Sharma  [Director of a State Owned Entity]
# 2                 Manuel Marín Guzmán  [Director of a State Owned Entity]
# 3                  Mohammed al Jadaan  [Director of a State Owned Entity]
# 4                         Olaf Scholz  [Director of a State Owned Entity]
# ...                               ...                                 ...
# 20918                     Hitoshi Ito  [Director of a State Owned Entity]
# 20919                 Alistair Dormer  [Director of a State Owned Entity]
# 20920               Hideaki Takahashi  [Director of a State Owned Entity]
# 20921                     Harish Bhat  [Director of a State Owned Entity]
# 20922           Mikhail Poluboyarinov  [Director of a State Owned Entity]
#
#       _source.data.number_aml_type_in_display_field  \
# 0                                                 0
# 1                                                 0
# 2                                                 0
# 3                                                 0
# 4                                                 0
# ...                                             ...
# 20918                                             0
# 20919                                             0
# 20920                                             0
# 20921                                             0
# 20922                                             0
#
#                                      _source.source_data  \
# 0      [{'data': {'aml_types': {'aml_type': array(['p...
# 1      [{'data': {'aml_types': {'aml_type': array(['p...
# 2      [{'data': {'aml_types': {'aml_type': array(['p...
# 3      [{'data': {'aml_types': {'aml_type': array(['p...
# 4      [{'data': {'aml_types': {'aml_type': array(['p...
# ...                                                  ...
# 20918  [{'data': {'aml_types': {'aml_type': array(['p...
# 20919  [{'data': {'aml_types': {'aml_type': array(['p...
# 20920  [{'data': {'aml_types': {'aml_type': array(['p...
# 20921  [{'data': {'aml_types': {'aml_type': array(['p...
# 20922  [{'data': {'aml_types': {'aml_type': array(['p...
#
#                               _source.data.names.aliases
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                          [Olaf Scholz]
# ...                                                  ...
# 20918                                               None
# 20919                 [Alistair Dormer, Alistair Dormer]
# 20920                                               None
# 20921  [Harish Bhat, Harish Bhat, Harish Bhat, Harish...
# 20922                                               None
#
# [20923 rows x 21 columns]
